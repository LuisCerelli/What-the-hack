# %% [markdown]
# # Reto 03-B-Chunking (Segmentación)

# %% [markdown]
# ## 1. Descripción General
#
# En este notebook, repasarás los conceptos de tokens y chunking. En el notebook anterior (`CH-03-A-Grounding`), pudimos proporcionar algo de contexto adicional para fundamentar el modelo. ¿Existe un límite para la cantidad de contexto adicional que podemos proporcionar al modelo? Desafortunadamente, la respuesta es sí. Existe un límite para la cantidad de tokens permitidos en la entrada y la salida combinadas según el modelo que se esté utilizando.
#
# Entonces, ¿qué son los tokens? Los tokens son una representación de cómo los modelos de Azure OpenAI procesan el texto. Son palabras o simplemente fragmentos de caracteres. Veamos el número total de tokens en la respuesta que obtuvimos del primer notebook del Desafío 3. Hay muchas formas de calcular tokens. En este notebook, echaremos un vistazo a la biblioteca `tiktoken` para contar los tokens.

# %% [markdown]
# ## 2. Comencemos con la Implementación
#
# Necesitarás importar los módulos necesarios. Las siguientes celdas son pasos de configuración de claves que ya completaste en los desafíos anteriores.

# %%
! pip install --upgrade click
! python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: click in /usr/local/python/3.12.1/lib/python3.12/site-packages (8.1.7)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 82.1 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.13.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.67.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in /home/codespace/.local/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.5.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /home/codespace/.local/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/codespace/.local/lib/python3.12/site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/codespace/.local/lib/python3.12/site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/python/3.12.1/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python -m pip install --upgrade pip
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import openai
import PyPDF3
import os
import json
import tiktoken
import spacy
from openai.error import InvalidRequestError

from dotenv import load_dotenv, find_dotenv
load_dotenv(find_dotenv())

from spacy.lang.en import English 
nlp = spacy.load("en_core_web_sm")

import langchain
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %% [markdown]
# Configura tu entorno para acceder a tus claves de Azure OpenAI. Consulta tu recurso de Azure OpenAI en el Portal de Azure para obtener información sobre tu punto de conexión y claves de Azure OpenAI.
#
# Por razones de seguridad, almacena tu información sensible en un archivo .env.

# %%
# Load your OpenAI credentials
API_KEY = os.getenv("OPENAI_API_KEY")
assert API_KEY, "ERROR: Azure OpenAI Key is missing"
openai.api_key = API_KEY

RESOURCE_ENDPOINT = os.getenv("OPENAI_API_BASE","").strip()
assert RESOURCE_ENDPOINT, "ERROR: Azure OpenAI Endpoint is missing"
assert "openai.azure.com" in RESOURCE_ENDPOINT.lower(), "ERROR: Azure OpenAI Endpoint should be in the form: \n\n\t<your unique endpoint identifier>.openai.azure.com"
openai.api_base = RESOURCE_ENDPOINT

openai.api_type = os.getenv("OPENAI_API_TYPE")
openai.api_version = os.getenv("OPENAI_API_VERSION")
model=os.getenv("CHAT_MODEL_NAME")

# %% [markdown]
# ## 3. Conteo de Tokens
#
# `tiktoken` utiliza una técnica llamada codificación de pares de bytes (BPE) para convertir el texto dado en tokens. Hay diferentes codificaciones disponibles para ayudar a procesar las palabras. En este norebook, utilizaremos `cl100k_base`.
#
# #### Tarea #1 del Estudiante:
#
# Cuenta el número de tokens en la respuesta final que recibimos en `CH-03-A-Grounding` completando la función `count_tokens` a continuación.

# %%
def count_tokens(string: str, encoding_name: str) -> int:
    """Returns the number of tokens in a text string."""
    encoding = tiktoken.get_encoding(encoding_name)
    num_tokens = len(encoding.encode(string))
    return num_tokens

# %%
count_tokens("tiktoken is great!", "cl100k_base")
# Out:
# 6

# %% [markdown]
# #### Tarea #2 del Estudiante:
#
# Ingresa el texto de la respuesta que recibiste en `CH-03-A-Grounding`. Ejecuta la celda a continuación para recuperar el número de tokens utilizando la función `count_tokens`.

# %%
text = """El ganador del torneo de individuales masculino de Wimbledon 2023 fue Carlos Alcaraz, mientras que la ganadora del torneo de individuales femenino fue Markéta Vondroušová.
"""

count_tokens(text, "cl100k_base")

print("There are " + str(count_tokens(text, "cl100k_base")) + " tokens: " + text)
# Out:
# There are 47 tokens: El ganador del torneo de individuales masculino de Wimbledon 2023 fue Carlos Alcaraz, mientras que la ganadora del torneo de individuales femenino fue Markéta Vondroušová.

# %% [markdown]
# Muy bien, ahora sabemos con cuántos tokens estamos trabajando. ¿Qué sucede si queremos agregar más contexto que el que ya pusimos en la variable de texto anterior? Si pensamos en nuestro escenario de Wimbledon, necesitaremos darle al modelo más contexto para ayudarlo a entender todo lo que necesita saber sobre el torneo. Más importante aún, todo lo que necesita saber para ayudar a responder tus preguntas al escribir el informe. Digamos que queremos proporcionar más contexto al modelo con un documento PDF. ¿Podemos intentar obtener un resumen del documento PDF para ayudarnos con nuestro trabajo?

# %% [markdown]
# #### Tarea #3 del Estudiante:
#
# En la celda siguiente, inserta la ruta del documento PDF, `CH3-data.pdf`, que se encuentra en la carpeta `/data` proporcionada. Ejecuta las tres celdas para ver la salida.

# %%
document = open(r'../data/CH3-data.pdf', 'rb') 
doc_helper = PyPDF3.PdfFileReader(document)

# %%
finaltext = ''
totalpages = doc_helper.getNumPages()
for eachpage in range(totalpages):
   p = doc_helper.getPage(eachpage)
   indpagetext = p.extractText()
   finaltext += indpagetext

clean_text = finaltext.replace("  ", " ").replace("\n", "; ").replace(';',' ')

# %%
prompt = f"What is the answer to the following question regarding the PDF document?\n\n{finaltext}\n\n" 
q = "Can you give me a summary of the document?"

try:
    final_prompt = prompt + q
    response = openai.ChatCompletion.create(engine=model, messages=final_prompt, max_tokens=50)
    answer = response.choices[0].text.strip()
    print(f"{q}\n{answer}\n")

except InvalidRequestError as e:
    print(e.error)
# Out:
# {
#   "code": null,
#   "message": "'What is the answer to the following question regarding the PDF document?\\n\\n \\nFormula 1 Power Unit Financial Regulations\\n \\n1\\n \\n16 August\\n \\n2022\\n \\n\u00a9 202\\n2\\n \\n\\n \\n \\n \\nIssue \\n1\\n \\n \\n \\n \\nFORMULA 1 \\nPOWER UNIT \\nFINANCIAL REGULATIONS\\n \\nPUBLISHED ON \\n16 August\\n \\n2022\\n \\nIssue \\n1\\n \\n \\nCONTENTS\\n \\n \\nArt\\n \\nCONTENTS\\n \\nPage(s)\\n \\n1.\\n \\nGENERAL PRINCIPLES\\n \\n................................\\n................................\\n................................\\n........\\n \\n2\\n \\n2.\\n \\nPOWER UNIT MANUFACTURER OBLIGATIONS\\n \\n................................\\n................................\\n....\\n \\n3\\n \\n3.\\n \\nEXCLUSIONS\\n \\n................................\\n................................\\n................................\\n.....................\\n \\n5\\n \\n4.\\n \\nADJUSTMENTS\\n \\n................................\\n................................\\n................................\\n..................\\n \\n8\\n \\n5.\\n \\nREPORTING R\\nEQUIREMENTS\\n \\n................................\\n................................\\n...........................\\n \\n12\\n \\n6.\\n \\nCOST CAP ADMINISTRATION\\n \\n................................\\n................................\\n...........................\\n \\n14\\n \\n7.\\n \\nCOST CAP ADJUDICATION PANEL\\n \\n................................\\n................................\\n.....................\\n \\n19\\n \\n8.\\n \\nCATEGORIES OF BREACH\\n \\n................................\\n................................\\n................................\\n.\\n \\n23\\n \\n9.\\n \\nSANCTIONS FOR BREACH\\n................................\\n................................\\n................................\\n.\\n \\n26\\n \\nAPPENDIX 1  DEFINITIONS AND INTERPRETATION\\n................................\\n................................\\n.........\\n \\n29\\n \\nAPPENDIX 2  ELIGIBLE TEST BENCHES\\n \\n................................\\n................................\\n...........................\\n \\n51\\n \\nAPPENDIX 3  TRANSITIONAL CAPITAL EXPENDITURE QUALIFYING ASSETS\\n \\n................................\\n......\\n \\n56\\n \\n \\n \\n \\n \\nFormula 1 Power Unit Financial Regulations\\n \\n2\\n \\n16 August\\n \\n2022\\n \\n\u00a9 202\\n2\\n \\n\\n \\n \\n \\nIssue \\n1\\n \\n \\n \\n1.\\n \\nGENERAL PRINCIPLES \\n \\nScope\\n \\n1.1\\n \\nThese \\nPower Unit \\nFinancial Regulations\\n \\ncome into force \\non\\n \\n1 January \\n202\\n3\\n. They form part of \\nthe terms and conditions \\nfor \\nthe \\nhomologation \\nof \\nPower Units to \\nbe supplied to\\n \\nF1 Team\\ns\\n \\nfor\\n \\nparticipation in the Championship\\n \\nfrom 2026 onwards\\n. Each \\nPower Unit Manufacturer\\n \\nintending to homologate Power Units\\n \\nfor supply \\nto an \\nF1 Team\\n(s)\\n \\nfor \\nparticipat\\nion\\n \\nin the \\nChampionship \\nfrom 2026 onwards \\nagrees to be bound by\\n,\\n \\nand \\nundertakes \\nto comply with\\n,\\n \\nthese \\nPower Unit \\nFinancial Regulations\\n \\nfrom \\nthe start of \\nits N\\n-\\n3 Full Year Reporting Period\\n.\\n \\nObjectives\\n \\n1.2\\n \\nThese \\nPower Unit \\nFinancial Regulations\\n \\nintroduce a \\nPower Unit \\nCost Cap that limits \\ncertain \\ncosts\\n \\nthat may be \\nincurred by or on behalf of \\na Power Unit Manufacturer \\nin each \\nFull Year \\nReporting Period, while leaving \\nthat \\nPower Unit Manufacturer \\nfree to decide how to allocate \\nresources within that \\nPower Unit \\nCost C\\nap. \\n \\n1.3\\n \\nThese \\nPower Unit \\nFinancial Regulations are\\n \\ndesigned to \\nhelp \\nachieve the following \\nobjectives \\n(the \\n\"\\nObjectives\\n\"\\n)\\n:\\n \\n(a)\\n \\nto promote \\nthe \\nlong\\n-\\nterm \\ncompetitive balance of the Championship\\n \\nin respect of \\nPower Units\\n;\\n \\n(b)\\n \\nto \\npromote the \\nlong\\n-\\nterm \\nsporting fairness\\n \\nof the Championship\\ ...
#   "param": null,
#   "type": "invalid_request_error"
# }

# %% [markdown]
# Como has podido observar, recibiste un mensaje de error después de ejecutar el fragmento de código anterior. El modelo alcanza su longitud de contexto máxima. Para los modelos GPT-3, el límite de tokens es de 4097 tokens. ¿Cómo solucionamos este problema al proporcionarle todo el contexto necesario, pero sin encontrarnos con el problema del límite de tokens?
#
# Para resolver este problema, podemos echar un vistazo a un concepto llamado Chunking (Segmentación).

# %% [markdown]
# ## 4. Chunking (Segmentación)
#
# La segmentación ayuda a limitar la cantidad de información que pasamos al modelo. La información que pasaremos son los trozos más relevantes de los datos en general. Hay muchas consideraciones que entran en juego al hacer segmentación. Por ejemplo, necesitas averiguar el mejor tamaño de chunk (trozo). Si los trozos son demasiado pequeños, puedes perder contexto importante. Si los trozos son demasiado grandes, pueden contener información innecesaria.
#
# A continuación se presentan algunas técnicas comunes de chunking.
#
# 1. Chunking con trozos más pequeños
# 2. Chunking dividiendo las oraciones
# 3. Chunking con superposición de oraciones
# 4. Chunking de forma recursiva
#
# Veamos estas técnicas en acción.

# %% [markdown]
# ### 4.1 Chunking con trozos más pequeños
#
# #### Tarea #4 del Estudiante:
#
# Agrega código en la celda siguiente. Utiliza la función `split()` para dividir el texto en trozos.

# %%
text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."

# Agrega tu código aquí # buscar sobre la funcion split() en google o chatgpt o w3school...

x = text.split()

for ch in x:
    print(ch)
# Out:
# The
# sun
# was
# setting
# over
# the
# horizon,
# casting
# a
# warm
# glow
# over
# the
# landscape.
# Birds
# chirped
# in
# the
# trees,
# and
# a
# gentle
# breeze
# rustled
# the
# leaves.
# In
# the
# distance,
# a
# herd
# of
# deer
# grazed
# in
# a
# meadow.
# The
# air
# was
# filled
# with
# the
# sweet
# scent
# of
# blooming
# flowers.
# It
# was
# a
# peaceful
# and
# serene
# scene,
# perfect
# for
# a
# quiet
# evening
# stroll.

# %% [markdown]
# ¿Qué puedes observar sobre los trozos devueltos? Si vieras cada trozo de manera individual, ¿podrías entender el significado semántico?

# %% [markdown]
# ### 4.2: Chunking dividiendo las oraciones
#
# #### Tarea #5 del Estudiante:
#
# Agrega código en la celda siguiente. Utiliza la biblioteca `spaCy` y específicamente la función `sents` para dividir el texto en trozos.

# %%
text = "Today was a fun day. I had lots of ice cream. I also met my best friend Sally and we played together at the new playground."

# Agrega tu código aquí # Buscar SpaCy y sents... en spaCy exemplos.... 
nlp_model = spacy.load("en_core_web_sm")
doc = nlp_model(text)
sents = list(doc.sents)

sents
# Out:
# [Today was a fun day.,
#  I had lots of ice cream.,
#  I also met my best friend Sally and we played together at the new playground.]

# %% [markdown]
# ¿Los resultados son mejores que el método en 4.1? La biblioteca `spaCy` ayuda a dividir el texto en oraciones individuales. Esto puede ser útil cuando intentas hacer resúmenes de texto. Puedes clasificar las oraciones individuales y usar los mejores resultados en el resumen.

# %% [markdown]
# ### 4.3: Chunking con superposición de oraciones
#
# #### Tarea #6 del Estudiante:
#
# Ejecuta el código mostrado a continuación para ver otro ejemplo de chunking. Como verás, el significado semántico se mantiene. En otras palabras, se conserva el contexto entre las oraciones. Esto es especialmente importante cuando estás buscando datos para obtener resultados relevantes o cuando estás resumiendo un fragmento de texto. Es importante capturar las relaciones entre las oraciones.

# %%
#SOLO EJECUTAR...

text = "The sun was setting over the horizon, casting a warm glow over the landscape. Birds chirped in the trees, and a gentle breeze rustled the leaves. In the distance, a herd of deer grazed in a meadow. The air was filled with the sweet scent of blooming flowers. It was a peaceful and serene scene, perfect for a quiet evening stroll."
doc = nlp(text)

sentences = list(doc.sents)
overlap = 1
chunks =[]

for i in range(len(sentences) - overlap):
    chunk = sentences[i : i + overlap + 1]
    chunks.append(chunk)

for chunk in chunks:
    print([sent.text for sent in chunk])
# Out:
# ['The sun was setting over the horizon, casting a warm glow over the landscape.', 'Birds chirped in the trees, and a gentle breeze rustled the leaves.']
# ['Birds chirped in the trees, and a gentle breeze rustled the leaves.', 'In the distance, a herd of deer grazed in a meadow.']
# ['In the distance, a herd of deer grazed in a meadow.', 'The air was filled with the sweet scent of blooming flowers.']
# ['The air was filled with the sweet scent of blooming flowers.', 'It was a peaceful and serene scene, perfect for a quiet evening stroll.']

# %% [markdown]
# ### 4.4: Chunking de forma recursiva usando LangChain
#
# #### Tarea #7 del Estudiante:
#
# Agrega los parámetros requeridos para `RecursiveCharacterSplitter` en la celda siguiente.

# %%
split_text = RecursiveCharacterTextSplitter(
   # Agrega los parámetros aquí
   chunk_size=50,  # Tamaño máximo de cada fragmento (en caracteres)
    chunk_overlap=20,  # Cantidad de caracteres que se superponen entre fragmentos
    separators=["\n\n", "\n", " ", ""]  # Prioridad de separación (párrafos, líneas, espacios, etc.)
)
# Divide el texto en fragmentos utilizando el método `create_documents`
docs = split_text.create_documents([clean_text])

# Visualiza los fragmentos resultantes
for doc in docs:
    print(doc.page_content)
# docs
# Out:
# Formula 1 Power Unit Financial Regulations
# Regulations     1     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1              FORMULA 1   POWER
# FORMULA 1   POWER UNIT   FINANCIAL REGULATIONS
# REGULATIONS     PUBLISHED ON   16 August     2022
# 16 August     2022     Issue   1        CONTENTS
# 1        CONTENTS        Art     CONTENTS
# CONTENTS     Page(s)     1.     GENERAL
# 1.     GENERAL PRINCIPLES
# PRINCIPLES     ................................
# ................................
# ................................  ........     2
# ........     2     2.     POWER UNIT
# 2.     POWER UNIT MANUFACTURER OBLIGATIONS
# OBLIGATIONS     ................................
# ................................  ....     3
# ....     3     3.     EXCLUSIONS
# EXCLUSIONS     ................................
# ................................
# ................................
# .....................     5     4.
# 5     4.     ADJUSTMENTS
# ADJUSTMENTS     ................................
# ................................
# ................................
# ..................     8     5.     REPORTING R
# 5.     REPORTING R  EQUIREMENTS
# EQUIREMENTS     ................................
# ................................
# ...........................     12     6.
# 12     6.     COST CAP ADMINISTRATION
# ................................
# ................................
# ...........................     14     7.
# 14     7.     COST CAP ADJUDICATION PANEL
# PANEL     ................................
# ................................
# .....................     19     8.
# 19     8.     CATEGORIES OF BREACH
# OF BREACH     ................................
# ................................
# ................................  .     23
# .     23     9.     SANCTIONS FOR BREACH
# FOR BREACH  ................................
# ................................
# ................................  .     26
# .     26     APPENDIX 1 DEFINITIONS AND
# 1 DEFINITIONS AND INTERPRETATION
# INTERPRETATION  ................................
# ................................  .........
# .........     29     APPENDIX 2 ELIGIBLE TEST
# 2 ELIGIBLE TEST BENCHES
# TEST BENCHES     ................................
# ................................
# ...........................     51     APPENDIX
# 51     APPENDIX 3 TRANSITIONAL CAPITAL
# CAPITAL EXPENDITURE QUALIFYING ASSETS
# ASSETS     ................................
# ......     56                 Formula 1 Power
# Formula 1 Power Unit Financial Regulations
# Regulations     2     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1           1.     GENERAL
# 1.     GENERAL PRINCIPLES      Scope     1.1
# Scope     1.1     These   Power Unit
# Power Unit   Financial Regulations     come
# come into force   on     1 January   202  3
# 1 January   202  3  . They form part of   the
# form part of   the terms and conditions   for
# conditions   for   the   homologation   of
# homologation   of   Power Units to   be supplied
# to   be supplied to     F1 Team  s     for
# Team  s     for     participation in the
# in the Championship     from 2026 onwards  . Each
# onwards  . Each   Power Unit Manufacturer
# Manufacturer     intending to homologate Power
# to homologate Power Units     for supply   to an
# for supply   to an   F1 Team  (s)     for
# Team  (s)     for   participat  ion     in the
# ion     in the   Championship   from 2026
# from 2026 onwards   agrees to be bound by  ,
# be bound by  ,     and   undertakes   to comply
# to comply with  ,     these   Power Unit
# Power Unit   Financial Regulations     from
# from   the start of   its N  -  3 Full Year
# N  -  3 Full Year Reporting Period  .
# Period  .     Objectives     1.2     These
# 1.2     These   Power Unit   Financial
# Unit   Financial Regulations     introduce a
# introduce a   Power Unit   Cost Cap that
# Cost Cap that limits   certain   costs     that
# costs     that may be   incurred by or on
# incurred by or on behalf of   a Power Unit
# of   a Power Unit Manufacturer   in each   Full
# in each   Full Year   Reporting Period, while
# Period, while leaving   that   Power Unit
# that   Power Unit Manufacturer   free to decide
# free to decide how to allocate   resources
# resources within that   Power Unit   Cost C
# Unit   Cost C  ap.      1.3     These   Power
# These   Power Unit   Financial Regulations
# Regulations are     designed to   help   achieve
# to   help   achieve the following   objectives
# objectives   (the   "  Objectives  "  )  :
# "  )  :     (a)     to promote   the   long  -
# the   long  -  term   competitive balance of
# balance of the Championship     in respect of
# in respect of   Power Units        (b)     to
# (b)     to   promote the   long  -  term
# long  -  term   sporting fairness     of the
# fairness     of the Championship     in respect
# in respect of Power   Units        and
# and     (c)     to   ensure   the long  -
# the long  -  term financial     stability and
# stability and     sustainability of the
# of the   Power Unit   Manufacturers  ,
# ,        while   preserv  ing     the     unique
# the     unique technolog  y and engineering
# y and engineering challenge     of F  ormula   1
# of F  ormula   1  .     1.4     These   Power
# These   Power Unit   Financial Regulations
# Regulations     wi  ll be interpreted and applied
# and applied by the     Cost Cap   Administration
# Administration  , the Cost Cap Adjudication
# Cap Adjudication Panel and the ICA   in a
# and the ICA   in a consistent manner that treats
# manner that treats   all     Power Unit
# all     Power Unit Manufacturers     equally and
# equally and that   advances   the Objectives
# the Objectives  .     1.5     The definitive
# The definitive version of these   Power Unit
# these   Power Unit   Financial Regulations     is
# Regulations     is the English version, which
# version, which   will be used should any dispute
# should any dispute arise as to their
# arise as to their interpretation. Defined w  ords
# Defined w  ords and phrases in   these   Power
# in   these   Power Unit   Financ  ial Regulations
# ial Regulations     (denoted by initial capital
# by initial capital letters) have the meaning
# have the meaning   indicated     in     Appendix
# in     Appendix   1   to these   Power Unit
# Power Unit   Financial Regulations  , unless
# , unless otherwise defined   in the body of
# in the body of these   Power Unit   Financial
# Unit   Financial Regulations  .     Unless
# .     Unless otherwise specified, references
# references   to   "  Articles  "     are to
# "     are to Articles     of these   Power Unit
# these   Power Unit   Financial Regulations  ,
# Regulations  ,     references to "may"   shall
# to "may"   shall mean in the sole discretion of
# sole discretion of such person or entity (as the
# or entity (as the context so requires),   and any
# and any   phrase introduced by the t  erms
# by the t  erms "including", "include", "in
# "include", "in particular" or any similar
# or any similar expression   shall be construed as
# be construed as illustrative and not   as   limit
# not   as   limit  ing     the sense of the words
# sense of the words preceding those   terms.
# terms.        1.6     If any part of these
# any part of these   Power Unit   Financial
# Unit   Financial Regulations     is found by a
# is found by a court or authority of
# or authority of   competent jurisdiction to be
# jurisdiction to be illegal, invalid or
# illegal, invalid or unenforceable, that part will
# that part will be deemed not to   form part of
# to   form part of these   Power Unit   Financial
# Unit   Financial Regulations  , and the legality,
# , and the legality, validity or enforceability
# or enforceability   of the remainder of these
# of these     Power Unit   Financial Regulations
# Regulations     will not be affected.
# be affected.        Formula 1 Power Unit
# 1 Power Unit Financial Regulations     3     16
# 3     16 August     2022     © 202  2
# © 202  2                Issue   1
# Issue   1           1.7     The Cost Cap
# The Cost Cap   Administration     shall
# shall periodically review these   Power Unit
# these   Power Unit   Financial Regulations  .
# Regulations  .   The  se   Power Unit   Financial
# Unit   Financial Regulations     may be amen  ded
# may be amen  ded and/or supplemented by the
# supplemented by the FIA   World   Motor     S
# Motor     S  port Cou  ncil from time to time
# from time to time  .     Accountability      1.8
# 1.8     Each   Power Unit Manufacturer
# Unit Manufacturer   must   ensure that all
# ensure that all Personnel are made   aware:
# made   aware:     (a)     of the Objectives,
# of the Objectives, content and substance of
# and substance of these   Power Unit   Financial
# Unit   Financial Regulations        and     (  b
# and     (  b  )         that the   Power
# that the   Power Unit Manufacturer     is
# Manufacturer     is subject to these   Power Unit
# these   Power Unit   Financial Regulations.
# Regulations.     1.9     E  ach   Power Unit
# E  ach   Power Unit Manufacturer     must
# must   ensure that   all relevant   Personnel
# Personnel are appropriately   informed and
# informed and trained with respect to the ways
# respect to the ways in which their areas of
# their areas of responsibility may   impact the
# may   impact the   Power Unit Man  ufacturer
# Man  ufacturer    se     Power   Unit   Financial
# Unit   Financial   Regulations.      1.10     E
# 1.10     E  ach   Power Unit Manufacturer
# Manufacturer     must   ensure that   the FIA
# that   the FIA     ethics and compliance   policy
# compliance   policy in force   from time to time
# from time to time with respect to these   Power
# to these   Power Unit   Financial Regulations is
# Regulations is clearly   communicated to all
# communicated to all Personnel.     2.     POWER
# 2.     POWER UNIT MANUFACTURER
# MANUFACTURER     OBLIGATIONS     2.1     Each
# 2.1     Each   Power Unit Manufacturer
# Manufacturer     must  :     (a)     demonstrate
# (a)     demonstrate its ongoing compliance with
# compliance with the   Power Unit   Cost Cap by
# Unit   Cost Cap by submitting   Reporting
# Reporting Documentation in respect of its
# in respect of its Reporting Group to the Cost Cap
# to the Cost Cap   Ad  ministration     by the
# by the Reporting Deadline in   respect of
# in   respect of   each Reporting Period and by
# Period and by   providing any further information
# further information requested from time to time
# from time to time by the Cost Cap
# by the Cost Cap   Administration         (b)
# (b)     cooperate fully and   in a timely
# and   in a timely manner   with     the Cost Cap
# the Cost Cap Administration in     the
# in     the   exercise of   its     regulatory
# its     regulatory function, including   any
# including   any investigation conducted by or on
# conducted by or on   behalf of the Cost Cap
# of the Cost Cap   Administration     pursuant to
# pursuant to     these   Power Unit
# Power Unit   Financial   Regulations     and/or
# and/or with the Financial Regulations
# Regulations           (c)     provide any
# (c)     provide any information     and
# information     and documentation     requested
# requested by or on behalf of the Cost   Cap
# of the Cost   Cap Administration   relevant to
# relevant to any actual  ,     potential     or
# potential     or   suspected     instance of
# instance of non  -  compliance with these
# with these   Power Unit   Financial Regulations
# Regulations     and/or with the Financial
# the Financial   Regulations    and     (d)
# and     (d)     faithfully execute its
# execute its obligations und  er these   Power
# er these   Power Unit   Financial Regulations
# Regulations     and act     at all times     in
# all times     in     a spirit of     G  ood   F
# of     G  ood   F  aith and   cooperation  .
# cooperation  .        Cap     on Relevant Costs
# on Relevant Costs     2.2     A     Power Unit
# A     Power Unit Manufacturer   must  :
# must  :     (a)     determine and report
# and report     its Relevant Costs against the
# Costs against the   Power Unit   Cost Cap in the
# Cost Cap in the   Power   Unit   Manufacturer
# Manufacturer      and        Formula 1 Power
# Formula 1 Power Unit Financial Regulations
# Regulations     4     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1           (b)     not   have
# not   have     Relevant Costs   in excess of
# in excess of the   Power Unit   Cost Cap   in
# Cost Cap   in   the applicable     Full   Year
# Full   Year   Reporting Period  .     The
# Period  .     The   Power Unit   Cost Cap     2.3
# Cost Cap     2.3     The amount of the "  Power
# of the "  Power Unit     Cost Cap  " shall be
# Cap  " shall be     as follows  :     (a)     in
# :     (a)     in the Full Year   Reporting
# Year   Reporting Period  s     ending on 31
# s     ending on 31 December 202  3, 31 December
# 202  3, 31 December 2024   and 31 December 2025
# 31 December 2025  , US Dollars 95,000,000  ,
# 95,000,000  , adjusted for Indexation        and
# and     (b)     in the Full Year Reporting
# Full Year Reporting Period ending on 31 December
# on 31 December 202  6     and in each subsequent
# in each subsequent   Full Year Reporting Period
# Reporting Period  , US Doll  ars 130,000,000  ,
# ars 130,000,000  , adjusted for Indexation  .
# Indexation  .     2.4     Where a   Power Unit
# a   Power Unit Manufacturer   has a Presentation
# has a Presentation Currency other than US
# other than US Dollars, the   Power Unit   Cost
# Power Unit   Cost Cap for that   Power Unit
# that   Power Unit Manufacturer     shall be
# shall be converted from US Dollars   into
# US Dollars   into   that   Power Unit
# that   Power Unit Manufacturer
# Manufacturer       Presentation Currency at the
# Currency at the Initial Applicable Rate. For
# Rate. For   illustrative purposes, the amount of
# the amount of the   Power Unit   Cost Cap in
# Unit   Cost Cap in selected Presentation
# Presentation   Currencies for the Full Year
# for the Full Year Reporting Period   ending on 31
# ending on 31 December 202  3  , as   referred
# 3  , as   referred to in   Article   2.3  (a)
# 2.3  (a)   (as  suming Indexation of zero)   is
# of zero)   is     as follows:     US Dollars
# US Dollars           Pounds Sterling
# Sterling           Euros           95,000
# 95,000     76,459     90,210
# 90,210        Reporting Group     2.5     F
# 2.5     F  or   the   purposes of   reporting
# of   reporting   Total     Costs     of the
# Costs     of the Reporting Group  ,     a
# Group  ,     a     Power Unit   Manufacturer
# Manufacturer       Reporting Group     shall
# Group     shall   comprise the   Power Unit
# the   Power Unit Manufacturer     together with
# together with  ,   where the   Power Unit
# the   Power Unit Manufacturer     has incurred
# has incurred less than 95% of the costs of
# 95% of the costs of the   Power Unit   Activities
# Unit   Activities undertaken by or on behalf of
# by or on behalf of the   Power Unit Manufacturer
# Unit Manufacturer     in the Reporting Period,
# Period,     such   additional   en  tities within
# en  tities within the   Power Unit Manufacturer
# Unit Manufacturer  's Legal G  ro  up S  tructure
# ro  up S  tructure     as are   determined in
# are   determined in accordance with     Article
# with     Article   2.6  .     2.6     The
# .     2.6     The   additional   entities to be
# entities to be included within   the
# within   the     Reporting Group   where   a
# where   a     Power Unit   Manufacturer     has
# has incurred less than 95% of the costs of
# 95% of the costs of the   Power Unit   Activities
# Unit   Activities undertaken   by or on behalf of
# by or on behalf of   that   Power Unit
# that   Power Unit Manufacturer     in the
# in the Reporting Period   shall be     the
# shall be     the entity   (other than the
# (other than the   Power Unit Manufacturer  )
# Manufacturer  ) within the   Power Unit
# the   Power Unit Manufacturer    Structure that
# Structure that incurred the greatest amount of
# greatest amount of costs     of the   Power Unit
# the   Power Unit   Activities undertaken   by or
# undertaken   by or on behalf of the   Power Unit
# of the   Power Unit Manufacturer     in the
# in the Reporting Period  , followed   (to the
# followed   (to the   extent required)   by   the
# by   the entity     within the   Power Unit
# the   Power Unit Manufacturer    that incurred
# that incurred     the next greatest amou  nt
# greatest amou  nt of   such   costs, and so on,
# costs, and so on, until   the entities included
# entities included   within   the     Reporting
# the     Reporting Group have     incurred  ,
# incurred  ,     in aggregate, 95%   or more
# 95%   or more   of the costs of the   Power
# of the   Power   Unit   Activities undertaken by
# undertaken by or on behalf of the   Power Unit
# of the   Power Unit Manufacturer     in the
# in the Reporting   Period.      2.7     I  n
# 2.7     I  n addition to those   entities
# those   entities   included     in the Reporting
# in the Reporting Group   pursuant to Article
# to Article  s     2.5     and   2.6  ,   a
# 2.6  ,   a     Power Unit Manufacturer     may
# may elect to include additional entities in
# entities in its Reporting Group      Formula 1
# Formula 1 Power Unit Financial Regulations
# Regulations     5     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1           from     w  ithin its
# w  ithin its Legal Group Structure     which
# Structure     which have incurred costs of
# incurred costs of   Power Unit   Activities
# Unit   Activities   undertaken on behalf of the
# on behalf of the   Power Unit Manufacturer     in
# Manufacturer     in the Reporting Period  .
# Period  .     2.8     For the purposes of
# For the purposes of Articles     2.5     to
# 2.5     to     2.7     (inclusive)  ,     t
# ,     t  he calculation of the costs of   Power
# costs of   Power Unit   Activities undertaken by
# undertaken by or on behalf of the   Power Unit
# of the   Power Unit Manufacturer     in the
# in the Reporting Period:     (a)     shall
# (a)     shall not include   Finance Costs and
# Finance Costs and   costs Directly Attributable
# Attributable to Marketing   Activities        (b)
# (b)     shall be made having adjusted
# having adjusted   out     any amounts in
# any amounts in connection with   Power Unit
# with   Power Unit   Activities recharged from one
# recharged from one member of the   Power Unit
# of the   Power Unit Manufacturer    egal Group
# egal Group   Structure to another  .     2.9
# .     2.9     I  n th  e     calculation of
# calculation of Relevant Costs, the costs of
# Costs, the costs of any   Power Unit   Activities
# Unit   Activities   incurred by     entities
# by     entities   within the   Power Unit
# the   Power Unit Manufacturer  's Legal Group
# 's Legal Group Structure but outside its
# but outside its Reporting Group  ,   other than
# ,   other than   Finance Costs and   costs
# Costs and   costs Directly Attributable to
# Attributable to   Marketing   Activities
# Activities undertaken   by any such entity,
# such entity,     must either be:     (a)
# be:     (a)     recharged a  t Fair Value to a
# Fair Value to a     Reporting Group     Entity
# Group     Entity and thereby included within
# included within Total   Costs     of the
# Costs     of the Reporting Group    or      (b)
# or      (b)     included   in Relevant Costs
# in Relevant Costs   at Fair Value by   way of an
# by   way of an Adjustment to Total     Cost  s
# Cost  s     of the   Reporting Group  , as a
# Group  , as a Related Party Transaction pursuant
# pursuant to Article 4.1(a)(i)  .     2.10     The
# .     2.10     The   Power Unit Manufacturer
# Manufacturer     should seek clarification from
# clarification from the Cost Cap Administration if
# Administration if it   is uncertain whether an
# whether an entity should be included in its
# be included in its Reporting Group.     3.     E
# 3.     E  XCLUSIONS     3.1     In
# 3.1     In calculating     Relevant Costs  ,
# Relevant Costs  ,     t  he following   costs
# following   costs and   amounts     within Total
# within Total Costs     of the   Reporting
# of the   Reporting Group   must     be excluded
# be excluded     (  "  Excluded Costs  "  )  :
# Costs  "  )  :     (a)     A  ll costs   D
# A  ll costs   D  irectly   A  ttributable to
# A  ttributable to Marketing Activities
# Activities        (b)     With respect to
# With respect to Heritage Asset Activities:
# Activities:     (i)     a  ll costs   D  irectly
# costs   D  irectly   A  ttributable to Heritage
# to Heritage Asset Activities        and     (ii)
# and     (ii)     if the Power Unit
# if the Power Unit Manufacturer can prove to the
# can prove to the satisfaction of   the   Cost Cap
# of   the   Cost Cap   Administration that an
# that an identifiable portion of the Consideration
# the Consideration provided to   any Heritage
# to   any Heritage Asset Personnel relates   to
# relates   to Heritage Asset Activities, that
# Activities, that portion     contributions
# contributions      (c)     All   Finance
# All   Finance     Costs        (d)     A  ll
# (d)     A  ll   Corporate Income Tax
# Income Tax        (e)     With respect to Non  -
# respect to Non  -  Power Unit   Activities:
# Activities:      (i)     a  ll costs   D
# a  ll costs   D  irectly   A  ttributable to
# A  ttributable to   Non  -  Power Unit
# -  Power Unit   Activities    and        Formula
# and        Formula 1 Power Unit Financial
# Unit Financial Regulations     6     16 August
# 6     16 August     2022     © 202  2
# © 202  2                Issue   1           (ii)
# 1           (ii)     if     the   Power Unit
# the   Power Unit Manufacturer     can prove to
# can prove to the satisfaction of the Cost Cap
# of the Cost Cap   Administration     that an
# that an identifiable portion of     the
# portion of     the following costs     relates to
# relates to     Non  -  Power Unit
# -  Power Unit   Activities  , that portion of
# , that portion of those costs  :     (A)
# :     (A)     Consideration   provided to  ,
# provided to  ,       contributions incurred in
# incurred in respect of  ,     an  y Personnel
# an  y Personnel     engaged in     both     Power
# both     Power Unit   Activities     and
# and   Non  -  Power Unit   Activities
# Activities        (B)     e  lectricity, gas
# lectricity, gas   and   water     costs
# water     costs     incurred     in the cours  e
# in the cours  e of both   Power   Unit
# Power   Unit   Activities and Non  -  Power
# and Non  -  Power Unit   Activities         (C)
# (C)     lease costs in respect of plant
# in respect of plant and equipment     used in the
# used in the cours  e of   both   Power Unit
# both   Power Unit   Activities and Non  -  Power
# and Non  -  Power Unit   Activities        and
# and     (D)     costs of   parts and
# of   parts and consumables  ,     and
# ,     and   outsourced     service  s  ,
# service  s  ,     incurred for   the
# for   the     maintenance of   an item of   plant
# an item of   plant or equipment used in the
# used in the course   of both   Power Unit
# both   Power Unit   Activities and Non  -  Power
# and Non  -  Power Unit   Activities      (f)
# (f)     All costs   D  irectly   A
# D  irectly   A  ttributab  le to Human
# le to Human Resources Activit  ies  ,
# Activit  ies  ,     Finance Act  ivit  ies     or
# ivit  ies     or     Legal Activit  ies
# Activit  ies        (g)     All Property   Cost
# Property   Cost  s        (h)     All   Employee
# All   Employee     Bonus Costs  , subject to
# Costs  , subject to a maximum   amount     in any
# amount     in any Full Year Reporting   Period
# Reporting   Period   of     the lower of  :
# lower of  :        (i)       20  % of the   Total
# % of the   Total   Fixed   Employee
# Employee     Remuneration        and
# and           (ii)     US Dollars 7,500,000
# Dollars 7,500,000  , adjusted for Indexation
# for Indexation           plus the amount of any
# the amount of any     amount of such Employee
# of such Employee Bonus Costs excluded pursuant to
# pursuant to this Article   3.1(h)
# 3.1(h)              (i)     All registration
# All registration   and administration   fees
# fees     payable to the FIA by a     Power Unit
# by a     Power Unit   Manufacturer     in
# Manufacturer     in relation to   the
# relation to   the registration and homologation
# and homologation of   its   Power Units in
# Power Units in   respect of     the
# respect of     the Championship taking place in
# taking place in the applicable Reporting Period
# Reporting Period      (j)     All   F  in  ancial
# All   F  in  ancial Penalties     in respect of
# in respect of any breach of   these   Power
# of   these   Power Unit   Financial   Regulations
# Regulations        (k)     All amounts of
# All amounts of depreciation,   amortisation,
# amortisation, impairment loss  ,     and
# loss  ,     and amounts as a result   of
# as a result   of revaluation or disposal of
# or disposal of tangible assets and intangible
# and intangible assets        (l)     All foreign
# (l)     All foreign exchange gains and losses
# and losses     recognised in profit or loss  ,
# profit or loss  , whether arising from
# arising from   settlement and/or re  -
# and/or re  -  measurement of monetar  y items
# of monetar  y items denominated in a foreign
# in a foreign   currency, or otherwise        (m)
# (m)     Where a Reporting Group Entity is
# Group Entity is required     by   applicable
# by   applicable   law  s     to pay employer
# to pay employer       social   security
# social   security   contributions  , the amount
# , the amount by which such mandatory
# such mandatory contributions exceed   13.8  % of
# exceed   13.8  % of the Total Employee
# Total Employee   Remuneration           Formula 1
# Formula 1 Power Unit Financial
# Unit Financial Regulations     7     16 August
# 7     16 August     2022     © 202  2
# © 202  2                Issue   1           (n)
# 1           (n)     All   Health   A  nd   S
# Health   A  nd   S  afety     Costs        (o)
# Costs        (o)     With respect to Customer
# respect to Customer Team Power Unit Activities:
# Unit Activities:     (i)     All costs Directly
# All costs Directly Attributable to Customer Team
# to Customer Team Power Unit Activities  and
# Activities  and     (ii)     If a Power Unit
# If a Power Unit Manufacturer can prove to the
# can prove to the satisfaction of the Cost Cap
# of the Cost Cap   Administration that an
# that an identifiable portion of the following
# of the following costs relates to   Customer Team
# to   Customer Team Power Unit Activities, that
# Activities, that portion of those costs:     (A)
# costs:     (A)       contributions incurred in
# incurred in respect of  ,     any P  ersonnel
# any P  ersonnel engaged in Power   Unit
# in Power   Unit Activities      (B)     e
# (B)     e  lectricity, gas and water costs
# gas and water costs incurred in the course of
# in the course of Power Unit   Activities      (C)
# Activities      (C)     lease costs in respect of
# costs in respect of plant and equipment used in
# equipment used in the course of   Power Unit
# of   Power Unit Activities  and     (D)     costs
# (D)     costs of parts and consumables, and
# consumables, and   outsourced services, incurred
# services, incurred for   the maintenance of an
# maintenance of an item of plant or equipment used
# or equipment used in the course   of Power Unit
# of Power Unit Activities      (p)     With
# (p)     With respect to Current Generation
# Current Generation Power Unit Activities     and
# Activities     and   in respect of the Full
# of the Full   Year Reporting Periods ending on 31
# ending on 31 December     2023, 31 December 2024
# 31 December 2024 and 31   December 2025     only
# 2025     only  :     (i)     All costs Directly
# All costs Directly Attributable to Current
# to Current Generation Power Unit Activities  and
# Activities  and     (ii)     If   a     Power
# If   a     Power Unit Manufacturer can prove
# can prove to the satisfaction of the Cost Cap
# of the Cost Cap   Administration that an
# that an identifiable portion of the following
# of the following costs relates to   Current
# to   Current Generation   Power Unit Activities,
# Unit Activities, that portion of those     costs:
# of those     costs:     (A)     Consideration
# Consideration provided to, and assoc
# to, and assoc    curity   contributions incurred
# incurred in respect of  ,     any Personnel
# ,     any Personnel engaged in     Power   Unit
# in     Power   Unit Activities      (B)     e
# (B)     e  lectricity, gas and water costs
# gas and water costs incurred in the course of
# in the course of Power Unit   Activities      (C)
# Activities      (C)     lease costs in respect of
# costs in respect of plant and equipment used in t
# equipment used in t  he course of   Power Unit
# of   Power Unit Activities  and     (D)     costs
# (D)     costs of parts and consumables, and
# consumables, and outsourced services, incurred
# services, incurred for   the maintenance of an
# maintenance of an item of plant or equipment used
# or equipment used in the course   of Power Unit
# of Power Unit Activities        (q)     A  ll
# (q)     A  ll   Employee     Termination
# Termination Benefits     (together with
# (together with   associated employer
# employer    security contributions  )  , incurred
# )  , incurred in the Full Year Reporting Periods
# Reporting Periods ending on 31   December   2023
# December   2023  , 31 December 2024     and 31
# 2024     and 31 December   2025    and
# 2025    and        Formula 1 Power Unit
# 1 Power Unit Financial Regulations     8     16
# 8     16 August     2022     © 202  2
# © 202  2                Issue   1
# Issue   1           (r)     All costs of
# All costs of Consideration other than
# other than Employee Termination Benefits
# Benefits (together with   asso    Employee prior
# Employee prior to the date on which they
# date on which they became a Reassigned Employee,
# Employee, subject to   a maximum aggregate amount
# aggregate amount of US Dollars 3,000,000  ,
# 3,000,000  , adjusted for Indexation  .
# .        3.2     If a cost within Total
# within Total     Costs of the Reporting Group is
# Reporting Group is   Directly Attributable to any
# Attributable to any combination   of the
# of the following activities  :     (a)
# :     (a)     Marketing Activities       (b)
# (b)     Heritage Asset Activities       (c)
# (c)     Non  -  Power Unit   Activities
# Activities       (d)     Human Resource  s
# Resource  s     Activities       (e)     Finance
# (e)     Finance Activities      (f)     Legal
# (f)     Legal Activities        (g)     C
# (g)     C  ustomer   T  eam   Power Unit
# T  eam   Power Unit Activities    and     (h)
# and     (h)     C  urrent   G  eneration P
# G  eneration P  ower Unit Activities  ,
# Activities  ,      such cost shall be an Excluded
# be an Excluded Cost.      3.3     For the
# 3.3     For the purposes of this Article 3,
# of this Article 3, where a     Power Unit
# a     Power Unit Manufacturer     has a
# has a Presentation   Currency other than US
# other than US Dollars  ,     amount  s
# ,     amount  s     expresse  d in US Dollars
# d in US Dollars shall be converted into that
# into that   Power Unit Manufacturer       4.
# 4.     ADJUSTMENTS     4.1     Unless
# 4.1     Unless stated otherwise in this
# otherwise in this Article   4  , i  n calculating
# , i  n calculating Relevant Costs, the following
# the following   a  djustments   to Total Costs
# to Total Costs   of the Reporting Group   must
# Group   must   be made:     (a)     Related Party
# Related Party Transactions, Exchange
# Exchange Transactions     and   F1   Team
# and   F1   Team Transactions:     A  ny
# A  ny   Related Party Transaction  , Exchange
# , Exchange Transaction     or F1   Team
# or F1   Team Transaction     in   connection
# in   connection with   a     Power Unit
# a     Power Unit   Activity     must be   includ
# must be   includ  ed in Relevant Costs   at
# Costs   at     not     less   than   Fair Value.
# than   Fair Value.        (b)     Offsetting of
# Offsetting of   i  ncome and   c  osts  :
# c  osts  :     If   a Reporting Group   Entity
# Group   Entity   has offset   any   income or
# any   income or   gains     within   its
# within   its     Total     Costs,   or any
# Costs,   or any   costs or losses     within
# losses     within   its   revenue,     the
# revenue,     the   Power Unit Manufacturer
# Manufacturer     must make an   upward
# make an   upward   adjustment     in     the
# in     the     calculation of     Relevant
# of     Relevant Costs to gross up   these
# up   these     amounts, unless  :     (i)
# :     (i)     such offsetting is permitted under
# is permitted under   its     applicable
# its     applicable accounting standards  ,
# standards  ,   with   the exception of     any
# of     any   income from a government incentive
# incentive scheme   in respect   of certain
# of certain research and development costs
# development costs included within Total Costs
# Total Costs     that   has been offset against
# been offset against such costs     in which case
# in which case   the Power Unit   Manufacturer
# Unit   Manufacturer      Formula 1 Power Unit
# 1 Power Unit Financial Regulations     9     16
# 9     16 August     2022     © 202  2
# © 202  2                Issue   1
# Issue   1           must make an upward
# must make an upward adjustment in the calculation
# in the calculation of Relevant Costs to gross
# Costs to gross   up these amounts        or
# or      (ii)     f  inance income   ha  s
# income   ha  s     be  en     offset against
# offset against Finance Costs, provided   that
# provided   that any   exclusion made pursuant to
# made pursuant to Article   3.1(c)     is made net
# is made net of finance income    or     (iii)
# or     (iii)     t  ax credits in respect of
# in respect of   C  orporate   Income T  ax   have
# Income T  ax   have     be  e  n     offset
# be  e  n     offset against tax   charges in
# tax   charges in respect   of   C  orporate
# of   C  orporate   Income T  ax, provided   that
# ax, provided   that any exclusion made   purs
# made   purs  uant to Article   3.1(d)     is made
# 3.1(d)     is made net of tax credits     in
# tax credits     in respect of Corporate   Income
# Corporate   Income Tax  .     (c)     Research
# (c)     Research and Development   c  osts  :
# c  osts  :        (i)     All costs     in
# All costs     in respect of     Research and
# of     Research and Development   for     Power
# for     Power Unit   Activities     must be
# must be included in Relevant Costs   in
# Costs   in     the Reporting Period in which they
# in which they are   incurred.     (ii)     If
# (ii)     If     a Reporting Group Entity
# Group Entity   has   defer  red     recognition
# red     recognition of   any costs   in respect
# costs   in respect of     Research and
# of     Research and Development   for   Power
# for   Power Unit   Activities   to   a
# to   a     subsequent   Reporting Period,   an
# Period,   an adjustment     must be made   in
# be made   in     the calculation of Relevant
# of Relevant   Costs   to ensure such costs are
# such costs are   recognised   with  in   the
# with  in   the Reporting Period in which   they
# in which   they are incurred  .        (d)
# .        (d)     Capitalisation of   Power Units
# of   Power Units  :     If a Reporting Group
# a Reporting Group Entity has capitalised any
# has capitalised any costs   in respect   of   a
# in respect   of   a Power Unit     during   the
# during   the Reporting Period, an adjustment
# an adjustment must be made in the calculation of
# the calculation of Relevant Costs   to ensure
# Costs   to ensure such costs are recognised
# are recognised within the Reporting Period in
# Reporting Period in which they are   incurred.
# are   incurred.     (e)     Capital Expenditure
# Expenditure  :     (i)     The amount (if any) by
# amount (if any) by which   the Capital
# which   the Capital Expenditure Amount     for
# Amount     for     the Full Year   Reporting
# Year   Reporting Period exceeds the Capital
# exceeds the Capital Expenditure   Limit     must
# Limit     must be included in   the calculation
# the calculation of Relevant Costs  .     (ii)
# Costs  .     (ii)     If the costs incurred as
# costs incurred as part of a Related Party
# of a Related Party Transaction, Exchange
# Exchange   Transaction or   F1 Team
# or   F1 Team     Transaction meet the definition
# meet the definition of paragraphs (a) or   (b) of
# (a) or   (b) of the definition of Capital
# of Capital Expenditure, such costs must be
# such costs must be included in   Capital
# in   Capital Expenditure at not less   than Fair
# less   than Fair Value.     (f)     Inventories
# Inventories  :     (i)     I  f the
# (i)     I  f the accounting treatment of   I
# treatment of   I  nventories     within Total
# within Total Costs   of the Reporting   Group
# Reporting   Group   varies from the   following
# the   following   requirements  , the   Power
# , the   Power Unit Manufacturer     must make an
# must make an   a  djustment in the
# a  djustment in the calculation of Relevant Costs
# of Relevant Costs     to reflect   these
# reflect   these   requirements  :     (A)     the
# :     (A)     the cost of an item of Used
# of an item of Used Inventories must be recognised
# must be recognised in full as   an expense in
# an expense in   the Full Year Reporting Period
# Reporting Period   in which it was first used
# it was first used   in respect of the     ,
# of the     , provided      Formula 1 Power Unit
# 1 Power Unit Financial Regulations     10     16
# 10     16 August     2022     © 202  2
# © 202  2                Issue   1
# Issue   1           that where such use occurs p
# such use occurs p  rior to 1 January   of its N
# January   of its N  -  3 Full Year   Reporting
# Year   Reporting Period and the item is re  -
# the item is re  -  used during the N  -  3 Full
# the N  -  3 Full Year   Reporting Period  , the
# Period  , the cost of that item of Used
# that item of Used Inventories must be
# must be   recognised in full as an expense     in
# an expense     in the   N  -  3   Full Year
# N  -  3   Full Year Reporting Period        (B)
# Period        (B)     the cost of     an item of
# of     an item of Unused Inventories must not be
# must not be recognised in   the Reporting Period
# Reporting Period  and     (C)     the cost of
# the cost of   an item of   Redundant
# item of   Redundant Inventories   (which has not
# (which has not been   recognised in a previous
# in a previous Full Year Reporting Period pursuant
# Period pursuant to any   other provision of this
# provision of this Article 4.1(f)(i  ))   must be
# ))   must be recognised in full as an   expense
# as an   expense in the Reporting Period.   W
# Period.   W  here practicable, the identification
# the identification   of Redundant Inventories
# Inventories must be carried out on an item  -  by
# on an item  -  by  -  item   basis. Otherwise,
# basis. Otherwise, groups of similar items may
# similar items may be considered   together  .
# together  .        (ii)     T  he cost of   an
# T  he cost of   an item of   I  nventories must
# I  nventories must comprise  :        (A)
# :        (A)     all costs of purchase  ,
# of purchase  ,   determined     on the same basis
# on the same basis as that used by   the   Power
# by   the   Power Unit Manufacturer     in its
# in its Audited Annual Financial   Statements
# Statements     in respect of the previous Full
# the previous Full Year Reporting Period
# Period           (B)     costs of conversion
# of conversion     (  including fixed production
# fixed production overheads allocated on   a basis
# on   a basis that is appropriate to the nature of
# to the nature of the product and method of
# and method of   production and on the basis of
# and on the basis of the entity's normal level of
# normal level of activity, and   applied
# and   applied consistently from o  ne   R
# from o  ne   R  eporting   P  eriod to another)
# eriod to another)      a  nd      (C)     other
# (C)     other costs incurred in bringing the
# in bringing the   item of   I  nventories to
# I  nventories to   its   present   location and
# location and condition  .     (iii)        In
# (iii)        In the event that an item of
# that an item of Redundant Inventories:     (A)
# (A)     has     not been used    and     (B)
# and     (B)     is not     of     a technical
# of     a technical specification that is
# that is     specific to the Power Units
# the Power Units   supplied to either the
# to either the Nominated Team or any     one
# or any     one     Customer Team     of   the
# Team     of   the Power Unit Manufacturer    and
# and     (C)     its cost   has     been
# has     been   recognised in full as an expense
# full as an expense     in the Reporting   Period
# Reporting   Period pursuant to paragraph (i)(C)
# to paragraph (i)(C) of this Article  ,     the
# Article  ,     the agg  regate cost of all such
# cost of all such items   must be allocated on a
# be allocated on a  n equal     pro  -  rata
# pro  -  rata   basis across the Nominated
# the Nominated Team and   each     Customer Team
# Customer Team of the Power Unit
# of the Power Unit   Manufacturer. The Power Unit
# The Power Unit Manufacturer must then make a
# must then make a downward   adjustment in the
# adjustment in the calculation of Relevant Cost
# of Relevant Cost  s for the Reporting Period
# Reporting Period equal   to the   aggregate
# the   aggregate   amount allocated to the
# allocated to the Customer     Teams.     (iv)
# Teams.     (iv)     In the event   that   an item
# that   an item of   Redundant Inventories
# Inventories     written off in a previous
# off in a previous   Reporting Period pursuant to
# Period pursuant to paragraph   (i)(  C  )     of
# (i)(  C  )     of this Article is used in a
# is used in a   subsequent Reporting Period, the
# Period, the   Power Unit Manufacturer     must
# must make an   adjustment in the calculation
# in the calculation of Relevant Costs for that
# Costs for that subsequent Reporting      Formula
# Formula 1 Power Unit Financial Regulations
# Regulations     11     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1           Period to add an
# Period to add an amount equal to that written
# to that written off in the previous Reporting
# Reporting   Pe  riod.        (g)     Unrecorded
# (g)     Unrecorded costs or losses:     If
# losses:     If     costs or     losses   incurred
# losses   incurred by a Reporting Group Entity
# Group Entity are not   recognised     within its
# within its   Total Costs,   which under the
# which under the applicable accounting standards
# standards should have been   recognised within
# recognised within profit or loss     during the
# loss     during the Reporting Per  iod  ,   an
# Per  iod  ,   an adjustment must be   made in the
# be   made in the calculation of Relevant Costs to
# Relevant Costs to ensure such costs are
# such costs are recognised     within     Relevant
# within     Relevant Costs   for     the Reporting
# the Reporting Period  .     (h)     Foreign
# (h)     Foreign   e  xchange   t  ransaction
# t  ransaction   c  osts:     (i)     Subject to
# (i)     Subject to Article   4.1(h)(ii)  , if a
# 4.1(h)(ii)  , if a Reporting Group Entity incurs
# Group Entity incurs a cost for a   transaction in
# a   transaction in a currency other than   the
# other than   the   Power Unit Manufacturer
# Manufacturer       Presentation Currency, the
# Currency, the   Power Unit Manufacturer     may
# may choose     to make   an     adjustment in
# adjustment in the calculation of Relevant
# of Relevant Costs     to reflect     the
# to reflect     the difference   between     such
# between     such cost     retranslated     into
# into   the   Power Unit Manufacturer
# Manufacturer    Presentation Currency using the
# Currency using the Applicable Rate,   and     the
# Rate,   and     the value at which those   costs
# which those   costs were recorded on ini  tial
# on ini  tial recognition within     Total Costs
# Total Costs     of the Reporting   Group  .
# Group  .     (ii)     If a     Power Unit
# If a     Power Unit Manufacturer     chooses to
# chooses to make such an adjustment, it must
# adjustment, it must be   made for all costs
# made for all costs within Total Costs     of the
# Costs     of the Reporting Group     that have
# Group     that have been   transacted in all
# transacted in all currencies other than the
# other than the   Power Unit Manufacturer
# Manufacturer    Presentation Currency  , unless
# Currency  , unless any such costs have otherwise
# have otherwise been excluded   from Total Costs
# from Total Costs of the Reporting Group
# the Reporting Group pursuant to Article 3  .
# to Article 3  .     (i)     Eligible External
# Eligible External Manufacturing Costs  :     If
# Costs  :     If a     Power Unit Manufacturer
# Manufacturer     has   recognised     Eligible
# Eligible External Manufacturing Costs
# Costs   within Total Costs   of   the
# of   the     Reporting Group  ,   it     must
# ,   it     must make a downward adjustment in
# adjustment in   the calculation     of Relevant
# of Relevant Costs     equal to   35% of
# to   35% of     any Eligible External
# Eligible External Manufacturing   Costs
# Costs     recognised  , subject to a maximum
# to a maximum amount of  :     (i)     US Dollars
# (i)     US Dollars 20,000,000   in respect of
# in respect of   each of   the Full Year
# of   the Full Year Reporting Periods   ending on
# Periods   ending on 31 December 2023, 31 December
# 2023, 31 December 2024 and 31 December 2025  ,
# December 2025  ,   adjusted for Indexation    and
# Indexation    and     (ii)     US Dollars
# (ii)     US Dollars 30,000,000, adjusted for
# adjusted for Indexation  ,   in respect of the
# in respect of the Full Year   Reporting Period
# Reporting Period ending on 31 December 2026 and
# December 2026 and   in respect of   each
# respect of   each   subsequent Full Year
# Full Year Reporting Period.     (j)     Election
# (j)     Election to defer:     (i)     In
# (i)     In respect of     e  ach     of   the
# e  ach     of   the Full Year Reporting Period  s
# Reporting Period  s     ending on 31 December
# on 31 December   2023   and     31 December 2
# 31 December 2  024  ,   a     Powe  r Unit
# a     Powe  r Unit Manufacturer may choose to
# may choose to make   an upward   a  djustment in
# a  djustment in the calculation of Relevant
# of Relevant Costs     up to a maximum   amount of
# maximum   amount of US Dollars 15,000,000  ,
# 15,000,000  , adjusted for Indexation  .
# .        Formula 1 Power Unit Financial
# Unit Financial Regulations     12     16 August
# 12     16 August     2022     © 202  2
# © 202  2                Issue   1           (ii)
# 1           (ii)     If a Power Unit
# If a Power Unit Manufacturer make  s     an
# make  s     an   a  djustment pursuant to Article
# pursuant to Article 4.1(j)(i)     within its Full
# within its Full Year Reporting Documentation
# Documentation that is submitted to Cost Cap
# to Cost Cap   Administration  :     (A)     it
# :     (A)     it cannot retrospectively be
# retrospectively be reversed    and     (B)
# and     (B)     the     Power Unit
# Power Unit     Manufacturer   must make an
# must make an equal and opposite   downward
# downward     a  djustment in the calculation of
# the calculation of Relevant Costs     for     the
# for     the   subsequent Full Year Reporting
# Full Year Reporting Pe  r  iod  .     (k)     New
# .     (k)     New Power Unit Manufacturers  :
# Manufacturers  :     A   Power Unit Man  u
# Power Unit Man  u  facturer that  ,     as at
# that  ,     as at the end of the applicable
# of the applicable Reporting Period   meets the
# meets the   definition of a New Power Unit
# of a New Power Unit Manufacturer  ,     must make
# ,     must make a downward   a  dju  s  tment
# a  dju  s  tment   in the   calculation of
# calculation of Relevant Costs     for the
# Costs     for the following amounts  :     (i)
# :     (i)     in respect of   both   its N  -  3
# both   its N  -  3     Full Year Reporting
# Full Year Reporting Period     and N  -  2 Full
# and N  -  2 Full Year   Reporting Period  , US
# Period  , US Dollars   10  ,000,000  ,
# 10  ,000,000  ,   multiplied by the Adjustment
# by the Adjustment Factor   for that New Power
# that New Power   Unit   Manufacturer and
# Manufacturer and   adjusted   for Indexation
# for Indexation  and     (ii)     in respect of
# in respect of its N  -  1 Full Year Reporting
# Full Year Reporting Period, US Dollars 5,000,000,
# Dollars 5,000,000,   multiplied by the Adjustment
# by the Adjustment Factor for that New Power
# that New Power   Unit   Manufacturer   and
# and   adjusted for Indexation  .     (l)
# .     (l)     Employee Termination Benefits:
# Benefits:     In the event that an individual
# an individual     in respect of whom th  e
# of whom th  e     exclusion   at     Article
# at     Article     3.1(q)     has   been applied
# has   been applied is re  -  engaged (either as
# ...
# / generator     Tester to allow detail and
# to allow detail and accurate   characterisation
# characterisation and measurement of ERS items
# of ERS items   from component to assembly     2
# to assembly     2     30     Inductive tester
# tester     Tester to allow detail and accurate
# and accurate   characterisation and measurement
# and measurement of ERS items   from component to
# from component to assembly     2     31
# 2     31     Motor test meters     HV test
# meters     HV test meters to measure MGU  -  K
# measure MGU  -  K winding   condition and quality
# and quality     7     3  2     3 axis   or CNC
# 3 axis   or CNC   resistance welding   machine
# welding   machine     Welding machine suitable
# machine suitable for the production of   ES
# of   ES   cell blocks     2     33     Cell tab
# 33     Cell tab cutting and   forming
# and   forming equipment     Workstation and
# Workstation and required tooling for cell tab
# for cell tab   cutting or forming     4     3  4
# 4     3  4     ES discharge   equipment
# equipment     ES discharge equipment to reduce
# equipment to reduce cell SOC to   required levels
# required levels for storage or transportation
# or transportation     1     3  5     Low   speed
# 5     Low   speed spin rig     A low power and
# A low power and speed MGU  -  K test bench to
# -  K test bench to   allow motor calibration,
# motor calibration, sensor specification
# specification   confirmation (rotor position /
# (rotor position / speed) and pre  -  production
# pre  -  production invertor functional testing
# testing     1     3  6     Nitrogen generator
# generator   and distribution   system      A
# system      A nitrogen   generator and
# generator and distribution system as   required
# as   required for manufacturing processes and
# processes and   safety features     2     3  7
# 2     3  7     Magnetic rotor flux   scanner
# flux   scanner     Machine to measure and
# to measure and characterise magnetic   rotor
# magnetic   rotor performance and quality     1
# quality     1     3  8     Rotational speed
# Rotational speed   sensor calibration rig
# calibration rig     Rig to   test and calibrate
# test and calibrate rpm sensors     1
# sensors     1     Materials laboratory equipment
# equipment     3  9     Tensile test rig     A
# test rig     A material sample tensile and
# sample tensile and compressive load   testing
# load   testing machine up to 300kN     1     40
# 1     40     Rotating bend fatigue   test
# bend fatigue   test machine     A fatigue sample
# A fatigue sample test machine producing
# machine producing   fatigue cycle   through
# cycle   through rotation with a bending   load
# a bending   load applied on samples up to 200mm
# samples up to 200mm in length     1     41
# 1     41     Axial fatigue test   machine
# test   machine     An axial fatigue sample test
# fatigue sample test machine including   an
# including   an environmental chamber     1     42
# 1     42     Heat treatment oven     Small
# oven     Small oven of up to 0.5m  3   capacity
# 0.5m  3   capacity with vacuum   to allow heat
# to allow heat treatment of material samples
# samples     1     4  3     Scanning electron
# Scanning electron   microscope (SEM)     A
# (SEM)     A general purpose SEM for material
# SEM for material inspection     1     4  4
# 1     4  4     Coating thickness        A
# thickness        A machine for Measurement of
# for Measurement of thin film and       microscope
# microscope     1        Formula 1 Power
# Formula 1 Power Unit Financial Regulations
# Regulations     59     16 August     2022     ©
# 2022     © 202  2                Issue   1
# Issue   1              (column 1)
# (column 1)     (column 2)     (column 3)
# (column 3)     No.     Equipment
# Equipment     Description     Qty     4  5
# Qty     4  5     Coating adhesion and
# adhesion and   hardness test rig     A scratch
# rig     A scratch test machine for coating
# machine for coating adhesion and   hardness
# and   hardness testing     1     4  6     Oil gas
# 4  6     Oil gas     chromatography (GC)
# (GC)   unit     An Oil GC measurement machine
# machine     3     47     Oil wear analysis
# Oil wear analysis   machine     Oil spectroscopy
# Oil spectroscopy   analyser for wear metal
# for wear metal   measurement.     2     48
# 2     48     Eddy current flaw   detector
# flaw   detector     An eddy current inspection
# current inspection device     for material   or
# for material   or component inspection     1
# inspection     1     4  9     Ultrasonic flaw
# Ultrasonic flaw   detector     An ultrasonic
# An ultrasonic scanning device for crack
# device for crack   detection in material samples
# material samples     2     Man  u  facturing
# Man  u  facturing equipment     50     Dynamic
# 50     Dynamic balancing   machine
# machine      Machine for measuring dynamic
# measuring dynamic balance of   rotating PU
# of   rotating PU components of up to 50Kg
# of up to 50Kg rotating   mass     2     51     Up
# 2     51     Up to   5 axis milling   machine
# milling   machine      A     milling machine
# milling machine   (up to 5 axis)   used for the
# used for the   manufacture of components with
# components with   a range of   movement of the
# movement of the tool in each of the X,Y and Z
# of the X,Y and Z   axes of less than 1300mm based
# than 1300mm based on a right hand   co  -
# right hand   co  -  ordinate system     2  5
# system     2  5     52     2 axis lathe      A 2
# axis lathe      A 2 axis turret lathe with live
# lathe with live turret tooling and   a tailstock
# and   a tailstock for producing cylindrical type
# cylindrical type   components     3     53     3
# 3     53     3 axis lathe      A 3 axis
# lathe      A 3 axis turret lathe with live turret
# with live turret tooling and   a second turning
# a second turning spindle for producing
# for producing   cylindrical type components     2
# components     2     54     7 axis turn  -  mill
# axis turn  -  mill      A 7 axis turn  -  mill
# axis turn  -  mill machine for producing
# for producing   complex turn  -  milled
# turn  -  milled components 2 turning   spindles
# turning   spindles (C1 & C2   Axis, with moving
# Axis, with moving C2 spindle   (W Axis)     4
# (W Axis)     4 axis milling/turning head (X1,
# head (X1, Y1, Z1 & B)     2 axis lower turning
# axis lower turning turret (X2, Z2)     Additional
# Z2)     Additional travelling steady rest and/or
# steady rest and/or   additional "in machine
# "in machine travelling robot" (IMTR)   for part
# (IMTR)   for part loading/unloading     5     5
# 5     5  5     Wire electro  -  discharge
# -  discharge   machine (wiring)      A multi
# A multi axis WEDM Machine for creating small
# for creating small   and intricate details not
# details not possible through   conventional
# conventional machining with a work envelope
# a work envelope   up to 500mm x 500mm x 400mm in
# x 500mm x 400mm in each of   three orthogonal
# three orthogonal axes     1     5  6
# 1     5  6     Electro  -  discharge
# -  discharge   machine (drilling)      A  n
# A  n     EDM Machine for drilling small
# for drilling small holes in   positions and
# in   positions and materials that are not
# that are not possible   through conventional
# conventional machining     2        Formula 1
# 2        Formula 1 Power Unit Financial
# Unit Financial Regulations     60     16 August
# 60     16 August     2022     © 202  2
# © 202  2                Issue   1
# 1              (column 1)     (column 2)
# (column 2)     (column 3)     No.
# 3)     No.     Equipment     Description     Qty
# Qty     5  7     Honing machine      A 3 axis
# A 3 axis honing machine for producing
# for producing accurate   internal diameters on
# diameters on   cylindrical components   excluding
# excluding honing heads     1     5  8
# 1     5  8     Crankshaft grinding   machine
# grinding   machine      A multi axis crankshaft
# axis crankshaft grinding machine for   producing
# for   producing PU crankshaft mains and pins
# mains and pins     2     5  9     Camshaft
# 5  9     Camshaft grinding   machine      A
# machine      A multi axis camshaft grinding
# camshaft grinding machine for   producing PU
# producing PU   camshaft journals and lobe
# journals and lobe   profiles     1     60     TIG
# 1     60     TIG welding machine     A 3 phase
# A 3 phase powered mobile manual tungsten  -
# manual tungsten  -  inert gas weld  ing set     1
# weld  ing set     1     61     Laser welding
# Laser welding machine      Laser welding
# Laser welding machine and associated
# and associated   equipment     1     62     Hot
# 1     62     Hot and cold wash   plant
# wash   plant      Any aqueous or detergent
# or detergent     hot, cold and ice   wash and
# and ice   wash and parts cleaner machines for
# machines for cleaning   various types of PU
# various types of PU components and tooling     15
# and tooling     15     63     Universal
# 63     Universal cylindrical   grinding
# grinding machine     A universal external and
# external and internal cylindrical   grinding
# grinding machine     3     64     Gear profile
# 64     Gear profile grinding   machine     A
# machine     A   machine for grinding of gear
# grinding of gear profiles for PU   gears     1
# PU   gears     1     65     Jig grinder     A
# Jig grinder     A general purpose jig grinding
# jig grinding machine     1     66     Crankshaft
# 66     Crankshaft polishing   machine     A
# machine     A dedicated crankshaft polishing
# polishing machine for   producing super fine
# super fine surface finishes on   crankshaft
# on   crankshaft journals     1     6  7
# 1     6  7     Manual surface   grinding
# surface   grinding machine     A manually
# A manually operated surface grinding machine
# grinding machine   for grinding engine components
# engine components     1     6  8     Piston skirt
# 8     Piston skirt turning   machine     A 2
# machine     A 2 axis turret lathe with
# turret lathe with dedicated oval turning
# oval turning   capabilities for producing piston
# producing piston skirt profiles     2     6  9
# 2     6  9     Piston   pin bore   machine
# bore   machine     A 2 axis boring machine with
# boring machine with dedicated oval   milling
# oval   milling capabilities for producing piston
# producing piston pin   bore profiles     1     70
# 1     70     High velocity oxygen   fuelled
# oxygen   fuelled (HVOF) coating   system     A
# system     A HVOF coating system including gun,
# including gun,   controller   and powder feeder
# and powder feeder     1     71     Nitride
# 71     Nitride furnace     A nitrogen fed
# A nitrogen fed furnace suitable for component
# for component   coating     1     72     Coating
# 72     Coating spray booth     A 1m  3
# A 1m  3     internal volume spray booth
# volume spray booth suitable for   coating
# for   coating application     2     73
# 2     73     Burnishing machine     A
# machine     A vibratory trough for polishing
# for polishing external   features of components
# of components     1     74     Guillotine     A
# Guillotine     A metal cutting guillotine
# cutting guillotine suitable for material   up to
# material   up to 10mm thickness x 2.5m cut     1
# x 2.5m cut     1        Formula 1 Power Unit
# 1 Power Unit Financial Regulations     61     16
# 61     16 August     2022     © 202  2
# © 202  2                Issue   1
# 1              (column 1)     (column 2)
# (column 2)     (column 3)     No.
# 3)     No.     Equipment     Description     Qty
# Qty     75     Sheet folder     A metal sheet
# A metal sheet folding machine suitable for up
# suitable for up to   2.5m     length fold     1
# length fold     1     76     CNC bender     A CNC
# bender     A CNC controlled pipe bender for up to
# bender for up to 150mm   outer diameter     x
# diameter     x 500mm pipe length     1     77
# 1     77     Crankshaft & camshaft
# & camshaft   inspection machine     A dedicated
# A dedicated high accuracy inspection tool
# inspection tool with   fixtures and multiple
# and multiple contact sensors for   measuring of
# for   measuring of crankshafts and camshafts
# and camshafts     1     78     Optical inspection
# Optical inspection     A bench top optical
# A bench top optical gauging tool for inspecting
# for inspecting   external features of components
# of components with up to   500mm x   4  0  0mm
# x   4  0  0mm   measuring range     4     79
# 4     79     Surface roughness   measurement
# measurement and   form tracing     A high
# tracing     A high accuracy surface roughness
# surface roughness tester and   form tracing
# and   form tracing machine for inspection of
# for inspection of   components      2     80
# 2     80     High powered optical
# powered optical   microscope     High powered
# High powered bench top microscope for
# top microscope for visually   inspecting PU
# inspecting PU components     8     81     MGU
# 8     81     MGU  -  K rotor bonding   machine
# bonding   machine     Automated MGU  -  K
# MGU  -  K   magnet bonding machine   for designs
# for designs compatible with Formula One     1
# Formula One     1     82     MGU  -  K rotor
# MGU  -  K rotor grinding   machine     A
# machine     A machine for accurate grinding of
# grinding of the external   diameter of MGU  -  K
# of MGU  -  K rotors     1     83     Sleeve press
# 83     Sleeve press     Indicated press for MGU
# press for MGU  -  K rotor banding for   designs
# for   designs compatible   with Formula One     1
# Formula One     1     84     Sleeve winding
# Sleeve winding   machine     A precision
# A precision winding machine for composite
# for composite   sleeves on mandrel for press fit
# for press fit or directly onto   the MGU  -  K
# the MGU  -  K rotor        85     MGU  -  K
# 85     MGU  -  K rotor   magnetising
# magnetising   equipment     A fixture and power
# A fixture and power supply for magnetising the
# magnetising the   MGU  -  K rotor     1     86
# 1     86     MGU  -  K stator   production
# production      Machinery, tool or fixture for
# tool or fixture for production of   MGU  -  K
# of   MGU  -  K stator including winding,
# including winding, stripping or   impregnation
# or   impregnation processes     3     8  7
# 3     8  7     Assembly press     Manual,
# press     Manual, pneumatic, hydraulic or servo
# hydraulic or servo general   assembly press
# assembly press     12     8  8     Gantry crane
# 8     Gantry crane     A gantry   crane of up to
# crane of up to 10m span        8  9     ALM
# 8  9     ALM rapid prototype,   machine  s
# machine  s     An additive manufacturing
# manufacturing machine     for the   production of
# the   production of   metallic or   non  -
# or   non  -  metallic   components with a build
# with a build volume of up to   6  00mm   x 600mm
# 6  00mm   x 600mm x 1000mm   in each of   the
# in each of   the   three orthogonal axes     6
# axes     6     90     Laser part     marking
# part     marking   machine     A laser part
# A laser part marking machine for
# marking machine for identification   of
# identification   of components in various
# in various materials and sizes     4     9  1
# 4     9  1     General purpose oven   or
# purpose oven   or refrigerators     Small general
# Small general purpose ovens or refrigerators
# or refrigerators for   components where precise
# where precise temperature control   6
# control   6        Formula 1 Power Unit Financial
# Unit Financial Regulations     62     16 August
# 62     16 August     2022     © 202  2
# © 202  2                Issue   1
# 1              (column 1)     (column 2)
# (column 2)     (column 3)     No.
# 3)     No.     Equipment     Description     Qty
# Qty     is   required with maximum capacity
# maximum capacity up to   0.25m  3     9  2     PU
# 3     9  2     PU Assembly tooling     Automated
# Automated   nutrunner or   fastener assembly
# fastener assembly tool   with torque control
# with torque control and recording     40     IT
# 40     IT eq  u  ipment     9  3     CFD
# 9  3     CFD supercomputer     <15,000 CPU
# <15,000 CPU core HPC cluster (or equivalent
# (or equivalent   CPU/GPU hardware) with   512  GB
# with   512  GB memory per   node, 2Gbs
# per   node, 2Gbs interconnect     including
# including switches  ,   1.0  PB cluster
# ,   1.0  PB cluster storage     1     9  4
# 1     9  4     Ethernet switches     24 port
# 24 port or similar local area network
# local area network connection   switch for IT
# switch for IT devices      100

# %% [markdown]
# Acabamos de realizar algunas fragmentaciones utilizando Langchain, un framework popular para crear aplicaciones utilizando modelos de lenguaje grandes. En los métodos anteriores, viste varios ejemplos de chunking. Langchain puede ayudar a hacer que el proceso de chunking sea más fácil con algunos de sus métodos. Estos métodos incluyen fragmentos de tamaño fijo, así como la fragmentación recursiva, que acabamos de ver.
#
# Por ejemplo, existe `CharacterTextSplitter` que dividirá el texto dado en un fragmento de tamaño fijo de un tamaño determinado y una superposición de caracteres determinada.
#
# `RecursiveCharacterTextSplitter` divide el texto en fragmentos más pequeños de manera iterativa. Nuevamente, puedes proporcionar el tamaño del fragmento y el recuento de superposición del fragmento.

# %% [markdown]
# La segmentación es una técnica importante por muchas razones. Ayuda a evitar el límite de tokens cuando se trabaja con grandes cantidades de datos y también optimiza la respuesta que recibimos del modelo. Encontrar la técnica de segmentación adecuada y el tamaño de fragmento es crucial para recibir respuestas relevantes.

# %% [markdown]
# ## Criterios de Éxito
#
# Para completar este desafío con éxito:
#
# * Demuestra una comprensión de los tokens y cómo calcularlos.
# * Demuestra una comprensión de la segmentación (chunking) experimentando con diferentes técnicas.
# * Sé capaz de entender la importancia de encontrar la solución de segmentación adecuada según si se captura o no el significado semántico.
